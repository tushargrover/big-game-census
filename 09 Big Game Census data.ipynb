# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_game = pd.read_excel(r"C:\Users\Acer\Desktop\uscensusbureau-big-game-census-data-visualization\Big Game Census data.xlsx")

# %%
df_game.head()
# Out:
#         Player Name Player Jersey Number Player Position  Player Age  \
# 0    Devin McCourty                  #32            S/FS          30
# 1    Danny Amendola                  #80        PR/WR/KR          32
# 2  Johnson Bademosi                  #29     CB/SPTM/RCB          27
# 3       Chris Hogan                  #15              WR          29
# 4     James Develin                  #46           RB/FB          29
#
#    Player Weight (lbs.) Years Played Player Birthplace (city, town, etc.)  \
# 0                   195            8                               Nanuet
# 1                   190            9                        The Woodlands
# 2                   206            6                        Silver Spring
# 3                   210            5                              Wyckoff
# 4                   255            5                        Gilbertsville
#
#   Player Birth State    Player Birthplace (Combo) Player College  ...  \
# ...

# %%
df_game.columns
# Out:
# Index(['Player Name', 'Player Jersey Number', 'Player Position', 'Player Age',
#        'Player Weight (lbs.)', 'Years Played',
#        'Player Birthplace (city, town, etc.)', 'Player Birth State',
#        'Player Birthplace (Combo)', 'Player College', 'Player Team',
#        'Conference',
#        '2016 Population Estimates (except where otherwise noted)',
#        'State GEO ID', 'Full GEOID', 'Latitude (player birthplace)',
#        'Longitude (player birthplace)', 'Number from City',
#        'Number of Records',
#        'American FactFinder Link for more Census data points',
#        'Quickfacts Link', 'State Data Link', 'Source (Population States 2017)',
#        'Birthplace, Population Data Source'],
#       dtype='object')

# %%
df_game = df_game.drop(['Number from City','Number of Records',
       'American FactFinder Link for more Census data points',
       'Quickfacts Link', 'State Data Link', 'Source (Population States 2017)',
       'Birthplace, Population Data Source' ], axis =1)

# %%
df_game = df_game.drop(['Player Birthplace (Combo)'], axis=1)

# %%
df_game
# Out:
#            Player Name Player Jersey Number Player Position  Player Age  \
# 0       Devin McCourty                  #32            S/FS          30
# 1       Danny Amendola                  #80        PR/WR/KR          32
# 2     Johnson Bademosi                  #29     CB/SPTM/RCB          27
# 3          Chris Hogan                  #15              WR          29
# 4        James Develin                  #46           RB/FB          29
# ..                 ...                  ...             ...         ...
# 113         Nick Foles                   #9              QB          28
# 114        Will Beatty                  #66           T/LOT          32
# 115       Donnie Jones                   #8           P/HLD          37
# 116  Kamu Grugier-Hill                  #54     LB/SPTM/RLB          23
# 117      Isaac Seumalo                  #73           G/ROG          24
#
#      Player Weight (lbs.) Years Played Player Birthplace (city, town, etc.)  \
# ...

# %%
df_game.columns
# Out:
# Index(['Player Name', 'Player Jersey Number', 'Player Position', 'Player Age',
#        'Player Weight (lbs.)', 'Years Played',
#        'Player Birthplace (city, town, etc.)', 'Player Birth State',
#        'Player College', 'Player Team', 'Conference', 'State GEO ID',
#        'Full GEOID', 'Latitude (player birthplace)',
#        'Longitude (player birthplace)'],
#       dtype='object')

# %%
df_game.corr()
# Out:
#                                Player Age  Player Weight (lbs.)  State GEO ID  \
# Player Age                       1.000000             -0.016997      0.027805
# Player Weight (lbs.)            -0.016997              1.000000      0.163214
# State GEO ID                     0.027805              0.163214      1.000000
# Latitude (player birthplace)     0.085980             -0.033874      0.005716
# Longitude (player birthplace)    0.083444             -0.136517      0.251143
#
#                                Latitude (player birthplace)  \
# Player Age                                         0.085980
# Player Weight (lbs.)                              -0.033874
# State GEO ID                                       0.005716
# Latitude (player birthplace)                       1.000000
# Longitude (player birthplace)                      0.383300
#
#                                Longitude (player birthplace)
# Player Age                                          0.083444
# ...

# %%
## no corelation found within the dataset

# %% [markdown]
# # FILE #2

# %%
df_game_loc = pd.read_excel(r"C:\Users\Acer\Desktop\uscensusbureau-big-game-census-data-visualization\All states Census 2017 Population Estimates.xlsx")

# %%
df_game_loc
# Out:
#           GEOID  GEOID2        Geography Name  April 1, 2010 - Census  \
# 0   0400000US01       1               Alabama                 4779736
# 1   0400000US02       2                Alaska                  710231
# 2   0400000US04       4               Arizona                 6392017
# 3   0400000US05       5              Arkansas                 2915918
# 4   0400000US06       6            California                37253956
# 5   0400000US08       8              Colorado                 5029196
# 6   0400000US09       9           Connecticut                 3574097
# 7   0400000US10      10              Delaware                  897934
# 8   0400000US11      11  District of Columbia                  601723
# 9   0400000US12      12               Florida                18801310
# 10  0400000US13      13               Georgia                 9687653
# 11  0400000US15      15                Hawaii                 1360301
# ...

# %%
df_game_loc.columns
# Out:
# Index(['GEOID', 'GEOID2', 'Geography Name', 'April 1, 2010 - Census',
#        'April 1, 2010 - Estimates Base',
#        'Population Estimate (as of July 1) - 2010',
#        'Population Estimate (as of July 1) - 2011',
#        'Population Estimate (as of July 1) - 2012',
#        'Population Estimate (as of July 1) - 2013',
#        'Population Estimate (as of July 1) - 2014',
#        'Population Estimate (as of July 1) - 2015',
#        'Population Estimate (as of July 1) - 2016',
#        'Population Estimate (as of July 1) - 2017'],
#       dtype='object')

# %%
df_game_loc = df_game_loc.drop(['April 1, 2010 - Census',
       'April 1, 2010 - Estimates Base',
       'Population Estimate (as of July 1) - 2010',
       'Population Estimate (as of July 1) - 2011',
       'Population Estimate (as of July 1) - 2012',
       'Population Estimate (as of July 1) - 2013',
       'Population Estimate (as of July 1) - 2014',
       'Population Estimate (as of July 1) - 2015',
       'Population Estimate (as of July 1) - 2016'], axis=1)

# %%
df_game_loc
# Out:
#           GEOID  GEOID2        Geography Name  \
# 0   0400000US01       1               Alabama
# 1   0400000US02       2                Alaska
# 2   0400000US04       4               Arizona
# 3   0400000US05       5              Arkansas
# 4   0400000US06       6            California
# 5   0400000US08       8              Colorado
# 6   0400000US09       9           Connecticut
# 7   0400000US10      10              Delaware
# 8   0400000US11      11  District of Columbia
# 9   0400000US12      12               Florida
# 10  0400000US13      13               Georgia
# 11  0400000US15      15                Hawaii
# 12  0400000US16      16                 Idaho
# 13  0400000US17      17              Illinois
# 14  0400000US18      18               Indiana
# 15  0400000US19      19                  Iowa
# 16  0400000US20      20                Kansas
# 17  0400000US21      21              Kentucky
# 18  0400000US22      22             Louisiana
# ...

# %%
df_game.isnull().sum()
# Out:
# Player Name                             0
# Player Jersey Number                    0
# Player Position                         0
# Player Age                              0
# Player Weight (lbs.)                    0
# Years Played                            0
# Player Birthplace (city, town, etc.)    0
# Player Birth State                      0
# Player College                          0
# Player Team                             0
# Conference                              0
# State GEO ID                            0
# Full GEOID                              0
# Latitude (player birthplace)            0
# Longitude (player birthplace)           0
# dtype: int64

# %%
df=df.dropna(how='all')

##drop all the rows which have null values

# %%
df_game.to_csv("df_game_cleaned.csv", index=False)

# %%
df_game_loc.to_csv("df_game_loc_cleaned.csv", index= False)
